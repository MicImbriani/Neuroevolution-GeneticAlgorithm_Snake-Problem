# %% [markdown]
# This version of the snake game allows you to implement and run your evolutionary algorithm

# %%
import random
import time
import turtle

# %%
XSIZE = YSIZE = 16 # Number of grid cells in each direction (do not change this)

# %% [markdown]
# Change headless to True when evolving your solution. You can then pickle your final solution, and run it with this set to True to visualize the result, if you wish. Note that, when using Turtle,  to run it again properly you might need to go to restart your kernel after the visualization has finished.

# %% [markdown]
# If you are running on the cloud, or on Google Colab, you can chose to remove the turtle and display code altogether and only run headless. You could then pickle your best solution and use this code to see it play.

# %%
HEADLESS = True

# %%
class DisplayGame:
    def __init__(self, XSIZE, YSIZE):
        # SCREEN
        self.win = turtle.Screen()
        self.win.title("EVCO Snake game")
        self.win.bgcolor("grey")
        self.win.setup(width=(XSIZE*20)+40,height=(YSIZE*20)+40)
        #self.win.screensize((XSIZE*20)+20,(YSIZE*20)+20)
        self.win.tracer(0)

        #Snake Head
        self.head = turtle.Turtle()
        self.head.shape("square")
        self.head.color("black")

        # Snake food
        self.food = turtle.Turtle()
        self.food.shape("circle")
        self.food.color("yellow")
        self.food.penup()
        self.food.shapesize(0.55, 0.55)
        self.segments = []

    def reset(self, snake):
        self.segments = []
        self.head.penup()
        self.food.goto(-500, -500)
        self.head.goto(-500, -500)
        for i in range(len(snake)-1):
            self.add_snake_segment()
        self.update_segment_positions(snake)
       
    def update_food(self,new_food):
        self.food.goto(((new_food[1]-9)*20)+20, (((9-new_food[0])*20)-10)-20)
        
    def update_segment_positions(self, snake):
        self.head.goto(((snake[0][1]-9)*20)+20, (((9-snake[0][0])*20)-10)-20)
        for i in range(len(self.segments)):
            self.segments[i].goto(((snake[i+1][1]-9)*20)+20, (((9-snake[i+1][0])*20)-10)-20)

    def add_snake_segment(self):
        self.new_segment = turtle.Turtle()
        self.new_segment.speed(0)
        self.new_segment.shape("square")
        self.new_segment.color("green")
        self.new_segment.penup()
        self.segments.append(self.new_segment)

# %%
class snake:
    def __init__(self, _XSIZE, _YSIZE):
        self.XSIZE = _XSIZE
        self.YSIZE = _YSIZE
        self.reset()

    def reset(self):
        self.snake = [[8,10], [8,9], [8,8], [8,7], [8,6], [8,5], [8,4], [8,3], [8,2], [8,1],[8,0] ]# Initial snake co-ordinates [ypos,xpos]    
        self.food = self.place_food()
        self.ahead = []
        self.snake_direction = "right"

    def place_food(self):
        self.food = [random.randint(1, (YSIZE-2)), random.randint(1, (XSIZE-2))]
        self.food = [8,15]
        while (self.food in self.snake):
            self.food = [random.randint(1, (YSIZE-2)), random.randint(1, (XSIZE-2))]
        return( self.food )
    
    def update_snake_position(self):
        self.snake.insert(0, [self.snake[0][0] + (self.snake_direction == "down" and 1) + (self.snake_direction == "up" and -1), self.snake[0][1] + (self.snake_direction == "left" and -1) + (self.snake_direction == "right" and 1)])

    def food_eaten(self):
        if self.snake[0] == self.food:                                            # When snake eats the food
            return True
        else:    
            last = self.snake.pop()  # [1] If it does not eat the food, it moves forward and so last tail item is removed
            return False
            
    def snake_turns_into_self(self):
        if self.snake[0] in self.snake[1:]:
            return True
        else:
            return False

    def snake_hit_wall(self):
        if self.snake[0][0] == 0 or self.snake[0][0] == (YSIZE-1) or self.snake[0][1] == 0 or self.snake[0][1] == (XSIZE-1):
            return True
        else:
            return False





    # SENSING FUNCTIONS
    def getAheadLocation(self):
        self.ahead = [ self.snake[0][0] 
                    + (self.snake_direction == "down" and 1) 
                    + (self.snake_direction == "up" and -1), 
                self.snake[0][1] 
                + (self.snake_direction == "left" and -1)
                + (self.snake_direction == "right" and 1)]
    
    def getRightLocation(self):
        self.right = [self.snake[0][0], self.snake[0][1] + 1]
        return self.right

    def getLeftLocation(self):
        self.left = [self.snake[0][0] + 1, self.snake[0][1]] 
        return self.left


    # Returns true if snake snake is at edges of grid
    def sense_wall_ahead(self):
        self.getAheadLocation()
        return( self.ahead[0] == 0 or self.ahead[0] == (YSIZE-1) or self.ahead[1] == 0 or self.ahead[1] == (XSIZE-1) )
        
    def sense_food_ahead(self):
        self.getAheadLocation()
        return self.food == self.ahead

    def sense_tail_ahead(self):
        self.getAheadLocation()
        return self.ahead in self.snake
    
    def sense_tail_right(self):
        state = self.getRightLocation() in self.snake
        return state
    
    def sense_tail_left(self):
        state = self.getLeftLocation() in self.snake
        return state

    # If dx is negative => food on snake's left else right
    # If dy is negative => food above snake else below
    def get_food_distance(self):
        self.dy = self.food[0] - self.snake[0][0]
        self.dx = self.food [1] - self.snake[0][1]
        return self.dx, self.dy

    def check_correct_direction(self):
        dx, dy = self.get_food_distance()
        if dx <= 0 and self.snake_direction == "left":
            return 1.0
        if dx >= 0 and self.snake_direction == "right":
            return 1.0
        if dy <= 0 and self.snake_direction == "up":
            return 1.0
        if dy >= 0 and self.snake_direction == "down":
            return 1.0
        else:
            return 0

    def sense_food_ahead_line(self):
        if self.food[0] == self.snake[0][0] and self.check_correct_direction == 1.0:
            distance = self.food[0] - self.snake[0][0]
            return distance
        if self.food[1] == self.snake[0][1] and self.check_correct_direction == 1.0:
            distance = self.food[1] - self.snake[0][1]
            return distance
        else:
            return 0

    def sense_food_radius(self):
        y = self.snake[0][0]
        x = self.snake[0][1]
        for distance in range(1,17):
            cell1 = [y-distance, x-distance]
            cell2 = [y-distance, x]
            cell3 = [y-distance, x+distance]
            cell4 = [y, x-distance]
            cell5 = [y, x+distance]
            cell6 = [y+distance, x-distance]
            cell7 = [y+distance, x]
            cell8 = [y+distance, x+distance]

            if y-distance < 0:
                cell1 = []
                cell2 = []
                cell3 = []
            if y+distance > 16:
                cell6 = []
                cell7 = []
                cell8 = []
            if x-distance < 0:
                cell1 = []
                cell4 = []
                cell6 = []
            if x+distance > 16:
                cell3 = []
                cell5 = []
                cell8 = []

            row1 = [cell1, cell2, cell3]
            row2 = [cell4, [y,x], cell5]
            row3 = [cell6, cell7, cell8]

            if self.food == row1[0]:
                return 0.1
            if self.food == row1[1]:
                return 0.2
            if self.food == row1[2]:
                return 0.3
            if self.food == row2[0]:
                return 0.4
            if self.food == row2[2]:
                return 0.5
            if self.food == row3[0]:
                return 0.6
            if self.food == row3[1]:
                return 0.7
            if self.food == row3[2]:
                return 0.8

        return 0

# %%
snake_game = snake(XSIZE,YSIZE)

# %%
if not HEADLESS:
    display = DisplayGame(XSIZE,YSIZE)

# %% [markdown]
# # CODE

# %% [markdown]
# <br>

# %%
def run_game(display,snake_game, headless, network):

    food_score = 0
    steps_score = 0
    penalty_score = 0
    total_score = 0

    just_started = True

    snake_game.reset()
    if not headless:
        display.reset(snake_game.snake)
        display.win.update()
    snake_game.place_food()
    game_over = False
    snake_direction = "right"

    flag = True
    while not game_over:

        # ****YOUR AI BELOW HERE******************

        #food_ahead = snake_game.sense_food_ahead_line()
        correct_direction = snake_game.check_correct_direction()
        print("CORRECT DIRECTION: ", correct_direction)

        distance_food_x, distance_food_y = snake_game.get_food_distance()
        tail_ahead = snake_game.sense_tail_ahead()
        tail_right = snake_game.sense_tail_right()
        tail_left = snake_game.sense_tail_left()

        wall_ahead = snake_game.sense_wall_ahead()
        

        # divide into different vars to assign to a single input neuron each
        food_in_radius = snake_game.sense_food_radius()
        food_top_left = 0
        food_top_mid = 0
        food_top_right = 0
        food_mid_left = 0
        food_mid_right = 0
        food_bot_left = 0
        food_bot_mid = 0
        food_bot_rigth = 0

        if food_in_radius == 0.1:
            food_top_left = 1.0
        if food_in_radius == 0.2:
            food_top_mid = 1.0
        if food_in_radius == 0.3:
            food_top_right = 1.0
        if food_in_radius == 0.4:
            food_mid_left = 1.0
        if food_in_radius == 0.5:
            food_mid_right = 1.0
        if food_in_radius == 0.6:
            food_bot_left = 1.0
        if food_in_radius == 0.7:
            food_bot_mid = 1.0
        if food_in_radius == 0.8:
            food_bot_rigth = 1.0


        if just_started == True:
            previous_position = 0
        else:
            previous_position = snake_game.snake

        print(food_in_radius)

        decision = network.feedForward([
            correct_direction,
            distance_food_x,
            distance_food_y,
            tail_ahead,
            tail_right,
            tail_left,
            wall_ahead,
            previous_position,
            food_top_left,
            food_top_mid,
            food_top_right,
            food_mid_left,
            food_mid_right,
            food_bot_left,
            food_bot_mid,
            food_bot_rigth
            ])
        print(decision)

        if decision >= 0 and decision < 0.25: 
            new_snake_direction = "right"
            print("right")
        if decision >= 0.25 and decision < 0.5:
            new_snake_direction = "left"
            print("left")
        if decision >= 0.5 and decision < 0.75:
            new_snake_direction = "down"
            print("down")
        if decision >= 0.75 and decision <= 1.0:
            new_snake_direction = "up"
            print("up")

        snake_game.snake_direction = new_snake_direction

        if snake_game.check_correct_direction():
            steps_score += 1
        if not snake_game.check_correct_direction():
            steps_score -= 3
        
        
        # ****YOUR AI ABOVE HERE******************
            
        snake_game.update_snake_position()

        # Check if food is eaten
        if snake_game.food_eaten():
            snake_game.place_food()
            food_score += 1

        # Game over if the snake runs over itself
        if snake_game.snake_turns_into_self():
            penalty_score += 1
            game_over = True
            print("Snake turned into itself!")

        # Game over if the snake goes through a wall
        if snake_game.snake_hit_wall():
            penalty_score += 1
            game_over = True
            print("Snake hit a wall!")

        if not headless:       
            display.update_food(snake_game.food)
            display.update_segment_positions(snake_game.snake)
            display.win.update()
            time.sleep(0.2) # Change this to modify the speed the game runs at when displayed.

    total_score = food_score + steps_score - penalty_score
    print("\nFINAL score - " + str(total_score))
    print()
    if not headless: turtle.done()
    
    return int(food_score), int(steps_score), int(penalty_score)

# %%
import numpy as np
import math

# %%
class MLP(object):
    def __init__(self, numInput, numHidden1, numHidden2, numOutput):
        self.fitness = 0
        self.numInput = numInput + 1 # Add bias node from input to hidden layer 1 only
        self.numHidden1 = numHidden1 # Feel free to adapt the code to add more biases if you wish
        self.numHidden2 = numHidden2
        self.numOutput = numOutput

        self.w_i_h1 = np.random.randn(self.numHidden1, self.numInput) 
        self.w_h1_h2 = np.random.randn(self.numHidden2, self.numHidden1) 
        self.w_h2_o = np.random.randn(self.numOutput, self.numHidden2)

        self.ReLU = lambda x : max(0,x)

    def softmax(self, x):
        e_x = np.exp(x - np.max(x))
        return e_x / e_x.sum()
    
    def feedForward(self, inputs):
        inputsBias = inputs[:]
        inputsBias.insert(len(inputs),1)             # Add bias input

        h1 = np.dot(self.w_i_h1, inputsBias)         # feed input to hidden layer 1
        h1 = [self.ReLU(x) for x in h1]              # Activate hidden layer1
        
        h2 = np.dot(self.w_h1_h2, h1)                 # feed layer 1 to hidden layer 2
        h2 = [self.ReLU(x) for x in h2]              # Activate hidden layer 2

        output = np.dot(self.w_h2_o, h2)             # feed to output layer
        output = self.softmax(output)   # Activate output layer
        output = np.max(output)
        return output

    def getWeightsLinear(self):
        flat_w_i_h1 = list(self.w_i_h1.flatten())
        flat_w_h1_h2 = list(self.w_h1_h2.flatten())
        flat_w_h2_o = list(self.w_h2_o.flatten())
        return( flat_w_i_h1 + flat_w_h1_h2 + flat_w_h2_o )

    def setWeightsLinear(self, Wgenome):
        numWeights_I_H1 = self.numHidden1 * self.numInput
        numWeights_H1_H2 = self.numHidden2 * self.numHidden1
        numWeights_H2_O = self.numOutput * self.numHidden2

        self.w_i_h1 = np.array(Wgenome[:numWeights_I_H1])
        self.w_i_h1 = self.w_i_h1.reshape((self.numHidden1, self.numInput))
        
        self.w_h1_h2 = np.array(Wgenome[numWeights_I_H1:(numWeights_H1_H2+numWeights_I_H1)])
        self.w_h1_h2 = self.w_h1_h2.reshape((self.numHidden2, self.numHidden1))

        self.w_h2_o = np.array(Wgenome[(numWeights_H1_H2+numWeights_I_H1):])
        self.w_h2_o = self.w_h2_o.reshape((self.numOutput, self.numHidden2))

# %%
from deap import base 
from deap import creator
from deap import tools

import random
import time

# %%
# Number of nodes in each layer
n_in = 16
n_h1 = 8
n_h2 = 6
n_out = 4

IND_SIZE = ((n_in + 1) * n_h1) + (n_h1 * n_h2) + (n_h2 * n_out)

# %%
myNet = MLP(n_in, n_h1, n_h2, n_out)

# %%
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, -1.0, 1.0)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=IND_SIZE)

# %%
def evaluate(indiv, myNet, game):
    myNet.setWeightsLinear(indiv)
    game.reset()
    food, steps, penalty = run_game(display, snake_game, HEADLESS, myNet)
    print("food: ", food, ",   steps: ", steps)
    #everything multiplied by 100
    #fitness = (steps) + ((2**food) + (food*500)) - (((.25 * steps)**1.3) * (food**1.2))
    #fitness = float(np.log(np.absolute(steps)+1))*15 + 5 + steps + food*500 - steps/2
    fitness = steps + (food * 500) - (penalty * 50)
    print("fitness: " + str(fitness))
    print("END")
    print()
    print("___________________")
    print()
    return int(fitness),

# %%
toolbox.register("evaluate", evaluate)
toolbox.register("select", tools.selTournament, tournsize=3)

toolbox.register("mutate", tools.mutGaussian, mu=0.0, sigma=0.5, indpb=0.1)

# %%
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %%
stats = tools.Statistics(key=lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("std", np.std)
stats.register("min", np.min)
stats.register("max", np.max)

# %%
logbook = tools.Logbook()

pop = toolbox.population(n=100)

# %%
game = snake_game

# %%
fitness = [toolbox.evaluate(indiv, myNet, game) for indiv in pop]
for ind, fit in zip(pop, fitness):
    ind.fitness.values = fit
# Out:
# 0.9850454466765968
# up
# CORRECT DIRECTION:  0
# 0
# 0.9636946331009041
# up
# CORRECT DIRECTION:  0
# 0
# 0.9791815043381901
# up
# CORRECT DIRECTION:  0
# 0
# 0.9875932380962118
# up
# CORRECT DIRECTION:  0
# 0
# 0.9905882538224348
# up
# CORRECT DIRECTION:  0
# 0.8
# 0.9950115120576222
# up
# CORRECT DIRECTION:  0
# 0
# 0.995050648342146
# up
# CORRECT DIRECTION:  0
# 0
# 0.9949470377461527
# up
# Snake hit a wall!
#
# FINAL score - -21
#
# food:  0 ,   steps:  -20
# fitness: -70
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9991569760475602
# up
# CORRECT DIRECTION:  0
# 0
# 0.9999360533621618
# up
# CORRECT DIRECTION:  0
# 0
# 0.9999904959695037
# up
# CORRECT DIRECTION:  0
# 0
# 0.999998578084175
# up
# CORRECT DIRECTION:  0
# 0
# 0.9999998481294461
# up
# CORRECT DIRECTION:  0
# 0.8
# 0.9999999578571483
# up
# CORRECT DIRECTION:  0
# 0
# 0.9999999979519159
# up
# CORRECT DIRECTION:  0
# 0
# 0.9999999990937096
# up
# Snake hit a wall!
#
# FINAL score - -21
#
# food:  0 ,   steps:  -20
# fitness: -70
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.7941070989137999
# up
# CORRECT DIRECTION:  0
# 0
# 0.7452935705914028
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.4312419243912159
# left
# Snake turned into itself!
#
# FINAL score - -4
#
# food:  0 ,   steps:  -3
# fitness: -53
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9912719702048545
# up
# CORRECT DIRECTION:  0
# 0
# 0.9989906946249254
# up
# CORRECT DIRECTION:  0
# 0
# 0.9992648708851386
# up
# CORRECT DIRECTION:  0
# 0
# 0.9994618498835377
# up
# CORRECT DIRECTION:  0
# 0
# 0.9996036332361199
# up
# CORRECT DIRECTION:  0
# 0.8
# 0.9998609285973623
# up
# CORRECT DIRECTION:  0
# 0
# 0.9997744109128612
# up
# CORRECT DIRECTION:  0
# 0
# 0.9999522534398703
# up
# Snake hit a wall!
#
# FINAL score - -21
#
# food:  0 ,   steps:  -20
# fitness: -70
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9478839545448827
# up
# CORRECT DIRECTION:  0
# 0
# 0.941257323122882
# up
# CORRECT DIRECTION:  0
# 0
# 0.9426146374374988
# up
# CORRECT DIRECTION:  0
# 0
# 0.9650850629435722
# up
# CORRECT DIRECTION:  0
# 0
# 0.9784813725164714
# up
# CORRECT DIRECTION:  0
# 0.8
# 0.9907619804286207
# up
# CORRECT DIRECTION:  0
# 0
# 0.9916578621007806
# up
# CORRECT DIRECTION:  0
# 0
# 0.9897195599494929
# up
# Snake hit a wall!
#
# FINAL score - -21
#
# food:  0 ,   steps:  -20
# fitness: -70
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.5139627595410068
# down
# CORRECT DIRECTION:  0
# 0
# 0.45681277466764403
# left
# CORRECT DIRECTION:  0
# 0
# 0.4801383797623525
# left
# CORRECT DIRECTION:  0
# 0
# 0.5006157864419042
# down
# CORRECT DIRECTION:  0
# 0
# 0.560105268677509
# down
# CORRECT DIRECTION:  0
# 0
# 0.6360066778389825
# down
# CORRECT DIRECTION:  0
# 0
# 0.730527282061865
# down
# CORRECT DIRECTION:  0
# 0
# 0.8053908156930163
# up
# Snake turned into itself!
#
# FINAL score - -17
#
# food:  0 ,   steps:  -16
# fitness: -66
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.
# up
# CORRECT DIRECTION:  0
# 0.8
# 0.9931336967623209
# up
# CORRECT DIRECTION:  0
# 0
# 0.9916352750505896
# up
# CORRECT DIRECTION:  0
# 0
# 0.9936222552542058
# up
# Snake hit a wall!
#
# FINAL score - -21
#
# food:  0 ,   steps:  -20
# fitness: -70
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9820487958541387
# up
# CORRECT DIRECTION:  0
# 0
# 0.9964146924394955
# up
# CORRECT DIRECTION:  0
# 0
# 0.9963505599647635
# up
# CORRECT DIRECTION:  0
# 0
# 0.9968071980489601
# up
# CORRECT DIRECTION:  0
# 0
# 0.9974933803203064
# up
# CORRECT DIRECTION:  0
# 0.8
# 0.9993781334724388
# up
# CORRECT DIRECTION:  0
# 0
# 0.9987627071682489
# up
# CORRECT DIRECTION:  0
# 0
# 0.9994598193416478
# up
# Snake hit a wall!
#
# FINAL score - -21
#
# food:  0 ,   steps:  -20
# fitness: -70
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.7926868781684205
# up
# CORRECT DIRECTION:  0
# 0
# 0.7433555028340283
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.7265828988452835
# down
# CORRECT DIRECTION:  0
# 0
# 0.9122420558424368
# up
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________

# %%
NGEN = 100

for g in range(NGEN):
    print("--GEN: {}-----------------------------------------------".format(g))

    offspring = toolbox.select(pop, len(pop))
    offspring = list(map(toolbox.clone, offspring))

    for mutant in offspring:
        toolbox.mutate(mutant)
        del mutant.fitness.values
    
    invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
    fitnesses = [toolbox.evaluate(indiv, myNet, game) for indiv in invalid_ind]
    for ind, fit in zip(invalid_ind, fitnesses):
         ind.fitness.values = fit
    
    pop[:] = offspring
    record = stats.compile(pop)
    logbook.record(gen=g, **record)
# Out:
# 0
# 0.5416568011861678
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9999506740130248
# up
# CORRECT DIRECTION:  0
# 0
# 0.7953581385508042
# up
# CORRECT DIRECTION:  0
# 0
# 0.991281567479667
# up
# CORRECT DIRECTION:  0
# 0
# 0.999639667060505
# up
# CORRECT DIRECTION:  0
# 0
# 0.9997737544804132
# up
# CORRECT DIRECTION:  0
# 0.8
# 0.9999973931390095
# up
# CORRECT DIRECTION:  0
# 0
# 0.9999108184393999
# up
# CORRECT DIRECTION:  0
# 0
# 0.9990756754328683
# up
# Snake hit a wall!
#
# FINAL score - -21
#
# food:  0 ,   steps:  -20
# fitness: -70
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9577450377903658
# up
# CORRECT DIRECTION:  0
# 0
# 0.7048671298067578
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.7232644828235214
# down
# CORRECT DIRECTION:  0
# 0
# 0.9883084697203395
# up
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.998116182801584
# up
# CORRECT DIRECTION:  0
# 0
# 0.5518757238019857
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.7440204564479209
# down
# CORRECT DIRECTION:  0
# 0
# 0.8234377458299964
# up
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.7653381147354857
# up
# CORRECT DIRECTION:  0
# 0
# 0.6500634243749007
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9975713338166406
# up
# CORRECT DIRECTION:  0
# 0
# 0.9883585607034107
# up
# CORRECT DIRECTION:  0
# 0
# 0.3870998203158277
# left
# CORRECT DIRECTION:  0
# 0
# 0.25
# left
# CORRECT DIRECTION:  0
# 0
# 0.36530083292542326
# left
# CORRECT DIRECTION:  0
# 0
# 0.939795084632444
# up
# CORRECT DIRECTION:  0
# 0
# 0.4302328084755804
# left
# CORRECT DIRECTION:  0
# 0
# 0.6672543477419399
# down
# CORRECT DIRECTION:  1.0
# 0
# 0.9977139530036854
# up
# Snake turned into itself!
#
# FINAL score - -20
#
# food:  0 ,   steps:  -19
# fitness: -69
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9999999999771008
# up
# CORRECT DIRECTION:  0
# 0
# 0.7783260218378669
# up
# CORRECT DIRECTION:  0
# 0
# 0.34555823587938017
# left
# CORRECT DIRECTION:  0
# 0
# 0.5018804534261662
# down
# CORRECT DIRECTION:  1.0
# 0
# 0.9386358767938834
# up
# Snake turned into itself!
#
# FINAL score - -8
#
# food:  0 ,   steps:  -7
# fitness: -57
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9999956779287054
# up
# CORRECT DIRECTION:  0
# 0
# 0.99094706071415
# up
# CORRECT DIRECTION:  0
# 0
# 0.25
# left
# CORRECT DIRECTION:  0
# 0
# 0.28547020093298514
# left
# CORRECT DIRECTION:  0
# 0
# 0.6362274262969737
# down
# CORRECT DIRECTION:  1.0
# 0
# 0.9993059225827512
# up
# Snake turned into itself!
#
# FINAL score - -11
#
# food:  0 ,   steps:  -10
# fitness: -60
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.993234680967943
# up
# CORRECT DIRECTION:  0
# 0
# 0.5416568011861678
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9304317936159882
# up
# CORRECT DIRECTION:  0
# 0
# 0.623449457580168
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9999999533359989
# up
# CORRECT DIRECTION:  0
# 0
# 0.65866673464759
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9195454804625294
# up
# CORRECT DIRECTION:  0
# 0
# 0.40556687507769174
# left
# CORRECT DIRECTION:  0
# 0
# 0.5367896114017578
# down
# Snake turned into itself!
#
# FINAL score - -2
#
# food:  0 ,   steps:  -1
# fitness: -51
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9999988537216823
# up
# CORRECT DIRECTION:  0
# 0
# 0.7349063845460064
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9995185144696094
# up
# CORRECT DIRECTION:  0
# 0
# 0.5935081292956573
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9987176834520043
# up
# CORRECT DIRECTION:  0
# 0
# 0.6807729750073818
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9979144341311774
# up
# CORRECT DIRECTION:  0
# 0
# 0.9432692095267263
# up
# CORRECT DIRECTION:  0
# 0
# 0.9425540296165906
# up
# CORRECT DIRECTION:  0
# 0
# 0.805564477851264
# up
# CORRECT DIRECTION:  0
# 0
# 0.9362114633497101
# up
# CORRECT DIRECTION:  0
# 0.8
# 0.9212595853811462
# up
# CORRECT DIRECTION:  0
# 0
# 0.9943413447361
# up
# CORRECT DIRECTION:  0
# 0
# 0.999250157397274
# up
# Snake hit a wall!
#
# FINAL score - -21
#
# food:  0 ,   steps:  -20
# fitness: -70
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9988274919062271
# up
# CORRECT DIRECTION:  0
# 0
# 0.6035592741759188
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9994693034048124
# up
# CORRECT DIRECTION:  0
# 0
# 0.5625588315701459
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9627025572016963
# up
# CORRECT DIRECTION:  0
# 0
# 0.25
# left
# CORRECT DIRECTION:  0
# 0
# 0.25
# left
# CORRECT DIRECTION:  0
# 0
# 0.3451582055793764
# left
# CORRECT DIRECTION:  0
# 0
# 0.4964620385763796
# left
# CORRECT DIRECTION:  0
# 0
# 0.5579006210348888
# down
# Snake turned into itself!
#
# FINAL score - -11
#
# food:  0 ,   steps:  -10
# fitness: -60
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.996826087802694
# up
# CORRECT DIRECTION:  0
# 0
# 0.4149318849234262
# left
# CORRECT DIRECTION:  0
# 0
# 0.5417578315118456
# down
# Snake turned into itself!
#
# FINAL score - -2
#
# food:  0 ,   steps:  -1
# fitness: -51
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.48549440433233065
# left
# Snake turned into itself!
#
# FINAL score - -4
#
# food:  0 ,   steps:  -3
# fitness: -53
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.5093780683041702
# down
# CORRECT DIRECTION:  0
# 0
# 0.8365439879416212
# up
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9960163313825976
# up
# CORRECT DIRECTION:  0
# 0
# 0.9709944340898927
# up
# CORRECT DIRECTION:  0
# 0
# 0.808889844363156
# up
# CORRECT DIRECTION:  0
# 0
# 0.25
# left
# CORRECT DIRECTION:  0
# 0
# 0.5456628191884171
# down
# CORRECT DIRECTION:  1.0
# 0
# 0.8373675703191561
# up
# Snake turned into itself!
#
# FINAL score - -11
#
# food:  0 ,   steps:  -10
# fitness: -60
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.45788545107304857
# left
# Snake turned into itself!
#
# FINAL score - -4
#
# food:  0 ,   steps:  -3
# fitness: -53
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9999999947023863
# up
# CORRECT DIRECTION:  0
# 0
# 0.7808083684930381
# up
# CORRECT DIRECTION:  0
# 0
# 0.2650947883536077
# left
# CORRECT DIRECTION:  0
# 0
# 0.4241152452860323
# left
# CORRECT DIRECTION:  0
# 0
# 0.5751214092759056
# down
# CORRECT DIRECTION:  1.0
# 0
# 0.9967074690536063
# up
# Snake turned into itself!
#
# FINAL score - -11
#
# food:  0 ,   steps:  -10
# fitness: -60
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.
# up
# CORRECT DIRECTION:  0
# 0.8
# 0.9350171187732269
# up
# CORRECT DIRECTION:  0
# 0
# 0.970902021463018
# up
# CORRECT DIRECTION:  0
# 0
# 0.9882417244507579
# up
# Snake hit a wall!
#
# FINAL score - -21
#
# food:  0 ,   steps:  -20
# fitness: -70
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.7584995056732888
# up
# CORRECT DIRECTION:  0
# 0
# 0.6712103100625781
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9841204875215991
# up
# CORRECT DIRECTION:  0
# 0
# 0.7046806342738824
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.858637562960233
# up
# CORRECT DIRECTION:  0
# 0
# 0.6227506889491784
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9996345129661519
# up
# CORRECT DIRECTION:  0
# 0
# 0.6232971437588427
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9968530189384787
# up
# CORRECT DIRECTION:  0
# 0
# 0.5680217303241679
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.996826087802694
# up
# CORRECT DIRECTION:  0
# 0
# 0.5770091621835199
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9440914954927732
# up
# CORRECT DIRECTION:  0
# 0
# 0.6852346186427045
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9984652143542986
# up
# CORRECT DIRECTION:  0
# 0
# 0.503076559966727
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9800701410796426
# up
# CORRECT DIRECTION:  0
# 0
# 0.8827736359945216
# up
# CORRECT DIRECTION:  0
# 0
# 0.9994536215147952
# up
# CORRECT DIRECTION:  0
# 0
# 0.999937951287866
# up
# CORRECT DIRECTION:  0
# 0
# 0.9999929536480805
# up
# CORRECT DIRECTION:  0
# 0.8
# 0.9997818854440715
# up
# CORRECT DIRECTION:  0
# 0
# 0.9999999091301177
# up
# CORRECT DIRECTION:  0
# 0
# 0.999999999999839
# up
# Snake hit a wall!
#
# FINAL score - -21
#
# food:  0 ,   steps:  -20
# fitness: -70
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.5274726688957695
# down
# CORRECT DIRECTION:  0
# 0
# 0.6441030974662185
# down
# CORRECT DIRECTION:  0
# 0
# 0.6202304737125374
# down
# CORRECT DIRECTION:  0
# 0
# 0.8390031744667914
# up
# Snake turned into itself!
#
# FINAL score - -5
#
# food:  0 ,   steps:  -4
# fitness: -54
# END
#
# ___________________
#
# CORRECT DIRECTION:  1.0
# 0.5
# 0.8587251068062972
# up
# CORRECT DIRECTION:  0
# 0
# 0.555988728215211
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________

# %%
logbook.header = "gen", "avg", "evals", "std", "min", "max"

import matplotlib.pyplot as plt
# %matplotlib inline
gen = logbook.select("gen")
avgs = logbook.select("avg")
stds = logbook.select("std")

# %%
plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14) 
plt.rc('legend', fontsize=14)

fig, ax1 = plt.subplots()
#line1 = ax1.plot(gen, avgs)
line1 = ax1.errorbar(gen, avgs, yerr=stds, errorevery=2)
ax1.set_xlabel("Generation")
ax1.set_ylabel("Mean Fitness")
# Out:
# Text(0, 0.5, 'Mean Fitness')

# %%
indiv1 = tools.selBest(pop, 1)[0]
toolbox.evaluate(indiv1, myNet, game)
# Out:
# CORRECT DIRECTION:  1.0
# 0.5
# 0.9999999633966059
# up
# CORRECT DIRECTION:  0
# 0
# 0.6226455338629168
# down
# Snake turned into itself!
#
# FINAL score - 1
#
# food:  0 ,   steps:  2
# fitness: -48
# END
#
# ___________________
# (-48,)

# %% [markdown]
# Below is what you would use for your evaluation. You would also use it to display your final (pickled and loaded) solution, with headless = False.

# %% [markdown]
# If you have run without headless (i.e. with the display) you will need to reset your kernel to run again. This appears to be an IPython issue with Turtle, but if you have a way to deal with that, do please let me know. You will probable only want to run it one-at-a-time anyway.
